# %% [markdown]
# <a href="https://colab.research.google.com/github/OsvaldoFloresC/OsvaldoFloresC/blob/main/Introduccion/graficas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráfica de $f(x)=x-3^{-x}$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def g(x):
   return x
# Función cuadrática.
def f(x):
    return x - 3**(-x)

# %%
def h(x):
  return -3**(-x)

# %%
f(-5), f(1)
# Out:
# (-248, 0.6666666666666667)

# %%
# Valores del eje X que toma el gráfico.
x=np.linspace(-10, 10,100)

# %%
# Graficar ambas funciones.
plt.figure(figsize=(10,10))
plt.plot(x, f(x))
plt.plot(x, g(x))
plt.plot(x, h(x))
plt.axhline(0, color="black")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.axvline(0, color="black")
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.title("Suma de Funciones")
plt.grid(color="pink")
plt.savefig("output.png")  #Guardar gráfico como imágen PNG.
# Mostrarlo.
plt.show()

# %% [markdown]
# Ejercicio 1: Graficar las funciones $x$ y $3^{-x}$ en una sola figura y comentar cómo su resta da origen a la gráfica de $f(x)$.
#
# Ejercicio 2: Agregar título, color, retícula, rótulos a los ejes y aumentar el tamaño de la gráfica.

# %% [markdown]
# Como podemos notar la función $f(x)= g(x)+h(x)$ por descomposicion de funciones puede verse como $g(x)= x$ y $h(x)= -3^{-x}$, graficamente podemos observa su comportamiento de amabas funciones por separdo y la linea azul como intersecta con $g(x)$ y $h(x)$, la linea azul es $f(x)= x-3^{-x}$
