# %% [markdown]
# <a href="https://colab.research.google.com/github/OsvaldoFloresC/OsvaldoFloresC/blob/main/ACTIVIDAD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

F = np.array([-5,1,9,25,55,105])
x = np.array([0,1,2,3,4,5])

# %%
F
# Out:
# array([ -5,   1,   9,  25,  55, 105])

# %%
type(F)
# Out:
# numpy.ndarray

# %%
#graficamos los datos
plt.scatter(x,F, color="orange", marker='+')
plt.title("Gráfica de los datos.")
plt.xlabel('x')
plt.ylabel('y')
plt.grid(color="black", linestyle="--")

plt.show()

# %%
def f(x):
  return x**3 - 2*x**2 + 7*x -5

x1=np.linspace(0,5,100)

# %%
#graficamos los datos
plt.plot(x1, f(x1))
plt.scatter(x,F, color="orange", marker='o')
plt.title("Gráfica de los datos.")
plt.xlabel('x')
plt.ylabel('y')
plt.grid(color="black", linestyle="--")

plt.show()

# %%
G=np.diff(f(x))
print(G)
# Out:
# [ 6  8 16 30 50]

# %%
G2=np.diff(G)
print(G2)
# Out:
# [ 2  8 14 20]

# %%
G3=np.diff(G2)
print(G3)
# Out:
# [6 6 6]

# %%
import scipy.special as sp

# %%
N=sp.binom(0,5,3)
print(N)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-116-8ef31c623b02> in <cell line: 1>()
# ----> 1 N=sp.binom(0,5,3)
#       2 print(N)
#
# TypeError: return arrays must be of ArrayType
